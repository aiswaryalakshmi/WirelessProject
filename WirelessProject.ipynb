# %% [markdown]
# <a href="https://colab.research.google.com/github/aiswaryalakshmi/WirelessProject/blob/master/WirelessProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python3

import json
from collections import defaultdict
import statistics
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import argparse
from google.colab import files
from matplotlib.pyplot import figure
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root_dir = 'drive/My Drive/WirelessProject'
import glob   
import ntpath
import os

desktop_path = root_dir + '/desktop/*'
mobile_path = root_dir + '/mobile/'
g2_path = root_dir + '/mobile_2G/'
g3_path = root_dir + '/mobile_3G/'
g4_path = root_dir + '/mobile_4G/'
desktop_files=glob.glob(desktop_path)
websites_list = list()
desktop_performanceScore_list = list()
mobile_performanceScore_list = list()
desktop_SI_list = list()
mobile_SI_list = list()
desktop_interactive_list = list()
mobile_interactive_list = list()
desktop_1stContentfulPaint_list = list()
mobile_1stContentfulPaint_list = list()
desktop_1stMeaningfulPaint_list = list()
mobile_1stMeaningfulPaint_list = list()
desktop_1stCpuIdle_list = list()
mobile_1stCpuIdle_list =list()
desktop_relPreconnect_list = list()
mobile_relPreconnect_list = list()
desktop_relPreload_list = list()
mobile_relPreload_list = list()
desktop_bootupTime_list = list()
mobile_bootupTime_list = list()
desktop_mainThreadWorkBreakdown_list = list()
mobile_mainThreadWorkBreakdown_list = list()
desktop_networkRtt_list = list()
mobile_networkRtt_list = list()
desktop_networkRequests_list = list()
mobile_networkRequests_list = list()
desktop_networkServerLatency_list = list()
mobile_networkServerLatency_list = list()
desktop_mainThreadTasks_list = list()
mobile_mainThreadTasks_list = list()
desktop_thirdPartySummary_list = list()
mobile_thirdPartySummary_list = list()
desktop_totalByteWeight_list = list()
mobile_totalByteWeight_list = list()
desktop_usesHttp2_list = list()
mobile_usesHttp2_list = list()
desktop_usesPassiveEventListeners_list = list()
mobile_usesPassiveEventListeners_list = list()
desktop_usesPlugins_list = list()
mobile_usesPlugins_list = list()

g2_performanceScore_list = list()
g3_performanceScore_list = list()
g2_SI_list = list()
g3_SI_list = list()
g2_interactive_list = list()
g3_interactive_list = list()
g2_1stContentfulPaint_list = list()
g3_1stContentfulPaint_list = list()
g2_1stMeaningfulPaint_list = list()
g3_1stMeaningfulPaint_list = list()
g2_1stCpuIdle_list = list()
g3_1stCpuIdle_list =list()
g2_relPreconnect_list = list()
g3_relPreconnect_list = list()
g2_relPreload_list = list()
g3_relPreload_list = list()
g2_bootupTime_list = list()
g3_bootupTime_list = list()
g2_mainThreadWorkBreakdown_list = list()
g3_mainThreadWorkBreakdown_list = list()
g2_networkRtt_list = list()
g3_networkRtt_list = list()
g2_networkRequests_list = list()
g3_networkRequests_list = list()
g2_networkServerLatency_list = list()
g3_networkServerLatency_list = list()
g2_mainThreadTasks_list = list()
g3_mainThreadTasks_list = list()
g2_thirdPartySummary_list = list()
g3_thirdPartySummary_list = list()
g2_totalByteWeight_list = list()
g3_totalByteWeight_list = list()
g2_usesHttp2_list = list()
g3_usesHttp2_list = list()
g2_usesPassiveEventListeners_list = list()
g3_usesPassiveEventListeners_list = list()
g2_usesPlugins_list = list()
g3_usesPlugins_list = list()

g4_performanceScore_list = list()
g4_SI_list = list()
g4_interactive_list = list()
g4_1stContentfulPaint_list = list()
g4_1stMeaningfulPaint_list = list()
g4_1stCpuIdle_list = list()
g4_relPreconnect_list = list()
g4_relPreload_list = list()
g4_bootupTime_list = list()
g4_mainThreadWorkBreakdown_list = list()
g4_networkRtt_list = list()
g4_networkRequests_list = list()
g4_networkServerLatency_list = list()
g4_mainThreadTasks_list = list()
g4_thirdPartySummary_list = list()
g4_totalByteWeight_list = list()
g4_usesHttp2_list = list()
g4_usesPassiveEventListeners_list = list()
g4_usesPlugins_list = list()

swebsites_list = list()
sdesktop_SI_list = list()
smobile_SI_list = list()
sdesktop_interactive_list = list()
smobile_interactive_list = list()
sdesktop_1stContentfulPaint_list = list()
smobile_1stContentfulPaint_list = list()
sdesktop_1stMeaningfulPaint_list = list()
smobile_1stMeaningfulPaint_list = list()
sdesktop_1stCpuIdle_list = list()
smobile_1stCpuIdle_list =list()

for desktop_file in desktop_files:
  head, tail = ntpath.split(desktop_file)
  websites_list.append(os.path.splitext(tail)[0])
  json_file = open(desktop_file)
  json_data = json.load(json_file)
  desktop_SI_list.append(json_data["audits"]["speed-index"]["numericValue"])
  desktop_interactive_list.append(json_data["audits"]["interactive"]["numericValue"])
  desktop_1stContentfulPaint_list.append(json_data["audits"]["first-contentful-paint"]["numericValue"])
  desktop_1stMeaningfulPaint_list.append(json_data["audits"]["first-meaningful-paint"]["numericValue"])
  desktop_1stCpuIdle_list.append(json_data["audits"]["first-cpu-idle"]["numericValue"])
  desktop_performanceScore_list.append(json_data["categories"]["performance"]["score"])
  desktop_relPreconnect_list.append(json_data["audits"]["uses-rel-preconnect"]["score"])
  desktop_relPreload_list.append(json_data["audits"]["uses-rel-preload"]["score"])
  desktop_bootupTime_list.append(json_data["audits"]["bootup-time"]["score"])
  desktop_mainThreadWorkBreakdown_list.append(json_data["audits"]["mainthread-work-breakdown"]["score"])
  desktop_networkRtt_list.append(json_data["audits"]["network-rtt"]["numericValue"])
  desktop_networkRequests_list.append(json_data["audits"]["network-requests"]["numericValue"])
  desktop_networkServerLatency_list.append(json_data["audits"]["network-server-latency"]["numericValue"])
  desktop_mainThreadTasks_list.append(json_data["audits"]["main-thread-tasks"]["numericValue"])
  desktop_thirdPartySummary_list.append(json_data["audits"]["third-party-summary"]["score"])
  desktop_totalByteWeight_list.append(json_data["audits"]["total-byte-weight"]["numericValue"])
  desktop_usesHttp2_list.append(json_data["audits"]["uses-http2"]["score"])
  desktop_usesPassiveEventListeners_list.append(json_data["audits"]["uses-passive-event-listeners"]["score"])
  desktop_usesPlugins_list.append(json_data["audits"]["plugins"]["score"])

  sdesktop_SI_list.append(json_data["audits"]["speed-index"]["score"])
  sdesktop_interactive_list.append(json_data["audits"]["interactive"]["score"])
  sdesktop_1stContentfulPaint_list.append(json_data["audits"]["first-contentful-paint"]["score"])
  sdesktop_1stMeaningfulPaint_list.append(json_data["audits"]["first-meaningful-paint"]["score"])
  sdesktop_1stCpuIdle_list.append(json_data["audits"]["first-cpu-idle"]["score"])

  mobile_json_file = open(mobile_path + tail)
  mobile_json_data = json.load(mobile_json_file)
  mobile_SI_list.append(mobile_json_data["audits"]["speed-index"]["numericValue"])
  mobile_interactive_list.append(mobile_json_data["audits"]["interactive"]["numericValue"])
  mobile_1stContentfulPaint_list.append(mobile_json_data["audits"]["first-contentful-paint"]["numericValue"])
  mobile_1stMeaningfulPaint_list.append(mobile_json_data["audits"]["first-meaningful-paint"]["numericValue"])
  mobile_1stCpuIdle_list.append(mobile_json_data["audits"]["first-cpu-idle"]["numericValue"])
  mobile_performanceScore_list.append(mobile_json_data["categories"]["performance"]["score"])
  mobile_relPreconnect_list.append(mobile_json_data["audits"]["uses-rel-preconnect"]["score"])
  mobile_relPreload_list.append(mobile_json_data["audits"]["uses-rel-preload"]["score"])
  mobile_bootupTime_list.append(mobile_json_data["audits"]["bootup-time"]["score"])
  mobile_mainThreadWorkBreakdown_list.append(mobile_json_data["audits"]["mainthread-work-breakdown"]["score"])
  mobile_networkRtt_list.append(mobile_json_data["audits"]["network-rtt"]["numericValue"])
  mobile_networkRequests_list.append(mobile_json_data["audits"]["network-requests"]["numericValue"])
  mobile_networkServerLatency_list.append(mobile_json_data["audits"]["network-server-latency"]["numericValue"])
  mobile_mainThreadTasks_list.append(mobile_json_data["audits"]["main-thread-tasks"]["numericValue"])
  mobile_thirdPartySummary_list.append(mobile_json_data["audits"]["third-party-summary"]["score"])
  mobile_totalByteWeight_list.append(mobile_json_data["audits"]["total-byte-weight"]["numericValue"])
  mobile_usesHttp2_list.append(mobile_json_data["audits"]["uses-http2"]["score"])
  mobile_usesPassiveEventListeners_list.append(mobile_json_data["audits"]["uses-passive-event-listeners"]["score"])
  mobile_usesPlugins_list.append(mobile_json_data["audits"]["plugins"]["score"])

  g2_json_file = open(g2_path + tail)
  g2_json_data = json.load(g2_json_file)
  g2_SI_list.append(g2_json_data["audits"]["speed-index"]["numericValue"])
  g2_interactive_list.append(g2_json_data["audits"]["interactive"]["numericValue"])
  g2_1stContentfulPaint_list.append(g2_json_data["audits"]["first-contentful-paint"]["numericValue"])
  g2_1stMeaningfulPaint_list.append(g2_json_data["audits"]["first-meaningful-paint"]["numericValue"])
  g2_1stCpuIdle_list.append(g2_json_data["audits"]["first-cpu-idle"]["numericValue"])
  g2_performanceScore_list.append(g2_json_data["categories"]["performance"]["score"])
  g2_relPreconnect_list.append(g2_json_data["audits"]["uses-rel-preconnect"]["score"])
  g2_relPreload_list.append(g2_json_data["audits"]["uses-rel-preload"]["score"])
  g2_bootupTime_list.append(g2_json_data["audits"]["bootup-time"]["score"])
  g2_mainThreadWorkBreakdown_list.append(g2_json_data["audits"]["mainthread-work-breakdown"]["score"])
  g2_networkRtt_list.append(g2_json_data["audits"]["network-rtt"]["numericValue"])
  g2_networkRequests_list.append(g2_json_data["audits"]["network-requests"]["numericValue"])
  g2_networkServerLatency_list.append(g2_json_data["audits"]["network-server-latency"]["numericValue"])
  g2_mainThreadTasks_list.append(g2_json_data["audits"]["main-thread-tasks"]["numericValue"])
  g2_thirdPartySummary_list.append(g2_json_data["audits"]["third-party-summary"]["score"])
  g2_totalByteWeight_list.append(g2_json_data["audits"]["total-byte-weight"]["numericValue"])
  g2_usesHttp2_list.append(g2_json_data["audits"]["uses-http2"]["score"])
  g2_usesPassiveEventListeners_list.append(g2_json_data["audits"]["uses-passive-event-listeners"]["score"])
  g2_usesPlugins_list.append(g2_json_data["audits"]["plugins"]["score"])

  g3_json_file = open(g3_path + tail)
  g3_json_data = json.load(g3_json_file)
  g3_SI_list.append(g3_json_data["audits"]["speed-index"]["numericValue"])
  g3_interactive_list.append(g3_json_data["audits"]["interactive"]["numericValue"])
  g3_1stContentfulPaint_list.append(g3_json_data["audits"]["first-contentful-paint"]["numericValue"])
  g3_1stMeaningfulPaint_list.append(g3_json_data["audits"]["first-meaningful-paint"]["numericValue"])
  g3_1stCpuIdle_list.append(g3_json_data["audits"]["first-cpu-idle"]["numericValue"])
  g3_performanceScore_list.append(g3_json_data["categories"]["performance"]["score"])
  g3_relPreconnect_list.append(g3_json_data["audits"]["uses-rel-preconnect"]["score"])
  g3_relPreload_list.append(g3_json_data["audits"]["uses-rel-preload"]["score"])
  g3_bootupTime_list.append(g3_json_data["audits"]["bootup-time"]["score"])
  g3_mainThreadWorkBreakdown_list.append(g3_json_data["audits"]["mainthread-work-breakdown"]["score"])
  g3_networkRtt_list.append(g3_json_data["audits"]["network-rtt"]["numericValue"])
  g3_networkRequests_list.append(g3_json_data["audits"]["network-requests"]["numericValue"])
  g3_networkServerLatency_list.append(g3_json_data["audits"]["network-server-latency"]["numericValue"])
  g3_mainThreadTasks_list.append(g3_json_data["audits"]["main-thread-tasks"]["numericValue"])
  g3_thirdPartySummary_list.append(g3_json_data["audits"]["third-party-summary"]["score"])
  g3_totalByteWeight_list.append(g3_json_data["audits"]["total-byte-weight"]["numericValue"])
  g3_usesHttp2_list.append(g3_json_data["audits"]["uses-http2"]["score"])
  g3_usesPassiveEventListeners_list.append(g3_json_data["audits"]["uses-passive-event-listeners"]["score"])
  g3_usesPlugins_list.append(g3_json_data["audits"]["plugins"]["score"])

  g4_json_file = open(g4_path + tail)
  g4_json_data = json.load(g4_json_file)
  g4_SI_list.append(g4_json_data["audits"]["speed-index"]["numericValue"])
  g4_interactive_list.append(g4_json_data["audits"]["interactive"]["numericValue"])
  g4_1stContentfulPaint_list.append(g4_json_data["audits"]["first-contentful-paint"]["numericValue"])
  g4_1stMeaningfulPaint_list.append(g4_json_data["audits"]["first-meaningful-paint"]["numericValue"])
  g4_1stCpuIdle_list.append(g4_json_data["audits"]["first-cpu-idle"]["numericValue"])
  g4_performanceScore_list.append(g4_json_data["categories"]["performance"]["score"])
  g4_relPreconnect_list.append(g4_json_data["audits"]["uses-rel-preconnect"]["score"])
  g4_relPreload_list.append(g4_json_data["audits"]["uses-rel-preload"]["score"])
  g4_bootupTime_list.append(g4_json_data["audits"]["bootup-time"]["score"])
  g4_mainThreadWorkBreakdown_list.append(g4_json_data["audits"]["mainthread-work-breakdown"]["score"])
  g4_networkRtt_list.append(g4_json_data["audits"]["network-rtt"]["numericValue"])
  g4_networkRequests_list.append(g4_json_data["audits"]["network-requests"]["numericValue"])
  g4_networkServerLatency_list.append(g4_json_data["audits"]["network-server-latency"]["numericValue"])
  g4_mainThreadTasks_list.append(g4_json_data["audits"]["main-thread-tasks"]["numericValue"])
  g4_thirdPartySummary_list.append(g4_json_data["audits"]["third-party-summary"]["score"])
  g4_totalByteWeight_list.append(g4_json_data["audits"]["total-byte-weight"]["numericValue"])
  g4_usesHttp2_list.append(g4_json_data["audits"]["uses-http2"]["score"])
  g4_usesPassiveEventListeners_list.append(g4_json_data["audits"]["uses-passive-event-listeners"]["score"])
  g4_usesPlugins_list.append(g4_json_data["audits"]["plugins"]["score"])

  smobile_SI_list.append(mobile_json_data["audits"]["speed-index"]["score"])
  smobile_interactive_list.append(mobile_json_data["audits"]["interactive"]["score"])
  smobile_1stContentfulPaint_list.append(mobile_json_data["audits"]["first-contentful-paint"]["score"])
  smobile_1stMeaningfulPaint_list.append(mobile_json_data["audits"]["first-meaningful-paint"]["score"])
  smobile_1stCpuIdle_list.append(mobile_json_data["audits"]["first-cpu-idle"]["score"])

# %%
plt.plot(websites_list, desktop_performanceScore_list,label = 'Desktop')
plt.plot(websites_list, mobile_performanceScore_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("Performance Score")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_relPreconnect_list,label = 'Desktop')
plt.plot(websites_list, mobile_relPreconnect_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("relPreconnect")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_relPreload_list,label = 'Desktop')
plt.plot(websites_list, mobile_relPreload_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("relPreLoad")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_bootupTime_list,label = 'Desktop')
plt.plot(websites_list, mobile_bootupTime_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("bootupTime")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_mainThreadWorkBreakdown_list,label = 'Desktop')
plt.plot(websites_list, mobile_mainThreadWorkBreakdown_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("mainThreadWorkBreakdown")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_networkRtt_list,label = 'Desktop')
plt.plot(websites_list, mobile_networkRtt_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("networkRtt")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_networkRequests_list,label = 'Desktop')
plt.plot(websites_list, mobile_networkRequests_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("networkRequests")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_networkServerLatency_list,label = 'Desktop')
plt.plot(websites_list, mobile_networkServerLatency_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("network-server-latency")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_mainThreadTasks_list,label = 'Desktop')
plt.plot(websites_list, mobile_mainThreadTasks_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("main-thread-tasks")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_thirdPartySummary_list,label = 'Desktop')
plt.plot(websites_list, mobile_thirdPartySummary_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("thirdPartySummary")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_totalByteWeight_list,label = 'Desktop')
plt.plot(websites_list, mobile_totalByteWeight_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("total-byte-weight")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_usesHttp2_list,label = 'Desktop')
plt.plot(websites_list, mobile_usesHttp2_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("uses HTTP2")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_usesPassiveEventListeners_list,label = 'Desktop')
plt.plot(websites_list, mobile_usesPassiveEventListeners_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("uses-passive-event-listeners")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_usesPassiveEventListeners_list,label = 'Desktop')
plt.plot(websites_list, mobile_usesPassiveEventListeners_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("uses-passive-event-listeners")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_usesPlugins_list,label = 'Desktop')
plt.plot(websites_list, mobile_usesPlugins_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("plugins")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_SI_list,label = 'Desktop')
plt.plot(websites_list, mobile_SI_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("Speed Index")
plt.legend()
plt.show()

plt.plot(websites_list, sdesktop_SI_list,label = 'Desktop')
plt.plot(websites_list, smobile_SI_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("Speed Index")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_interactive_list,label = 'Desktop')
plt.plot(websites_list, mobile_interactive_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("Interactive")
plt.legend()
plt.show()

plt.plot(websites_list, sdesktop_interactive_list,label = 'Desktop')
plt.plot(websites_list, smobile_interactive_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("Interactive")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_1stContentfulPaint_list,label = 'Desktop')
plt.plot(websites_list, mobile_1stContentfulPaint_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("First Contentful Paint")
plt.legend()
plt.show()

plt.plot(websites_list, sdesktop_1stContentfulPaint_list,label = 'Desktop')
plt.plot(websites_list, smobile_1stContentfulPaint_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("First Contentful Paint")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_1stCpuIdle_list,label = 'Desktop')
plt.plot(websites_list, mobile_1stCpuIdle_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("First CPU Idle")
plt.legend()
plt.show()

plt.plot(websites_list, sdesktop_1stCpuIdle_list,label = 'Desktop')
plt.plot(websites_list, smobile_1stCpuIdle_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("First CPU Idle")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_1stMeaningfulPaint_list,label = 'Desktop')
plt.plot(websites_list, mobile_1stMeaningfulPaint_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("First Meaningful Paint")
plt.legend()
plt.show()

plt.plot(websites_list, sdesktop_1stMeaningfulPaint_list,label = 'Desktop')
plt.plot(websites_list, smobile_1stMeaningfulPaint_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("First Meaningful Paint")
plt.legend()
plt.show()

# %%
plt.plot(websites_list, g2_performanceScore_list,label = '2G')
plt.plot(websites_list, g3_performanceScore_list,label = '3G')
plt.plot(websites_list, g4_performanceScore_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("Performance Score")
plt.legend()
plt.show()

plt.plot(websites_list, g2_relPreconnect_list,label = '2G')
plt.plot(websites_list, g3_relPreconnect_list,label = '3G')
plt.plot(websites_list, g4_relPreconnect_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("relPreconnect")
plt.legend()
plt.show()

plt.plot(websites_list, g2_relPreload_list,label = '2G')
plt.plot(websites_list, g3_relPreload_list,label = '3G')
plt.plot(websites_list, g4_relPreload_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("relPreLoad")
plt.legend()
plt.show()

plt.plot(websites_list, g2_bootupTime_list,label = '2G')
plt.plot(websites_list, g3_bootupTime_list,label = '3G')
plt.plot(websites_list, g4_bootupTime_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("bootupTime")
plt.legend()
plt.show()

plt.plot(websites_list, g2_mainThreadWorkBreakdown_list,label = '2G')
plt.plot(websites_list, g3_mainThreadWorkBreakdown_list,label = '3G')
plt.plot(websites_list, g4_mainThreadWorkBreakdown_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("mainThreadWorkBreakdown")
plt.legend()
plt.show()

plt.plot(websites_list, g2_networkRtt_list,label = '2G')
plt.plot(websites_list, g3_networkRtt_list,label = '3G')
plt.plot(websites_list, g4_networkRtt_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("networkRtt")
plt.legend()
plt.show()

plt.plot(websites_list, g2_networkRequests_list,label = '2G')
plt.plot(websites_list, g3_networkRequests_list,label = '3G')
plt.plot(websites_list, g4_networkRequests_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("networkRequests")
plt.legend()
plt.show()

plt.plot(websites_list, g2_networkServerLatency_list,label = '2G')
plt.plot(websites_list, g3_networkServerLatency_list,label = '3G')
plt.plot(websites_list, g4_networkServerLatency_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("network-server-latency")
plt.legend()
plt.show()

plt.plot(websites_list, g2_mainThreadTasks_list,label = '2G')
plt.plot(websites_list, g3_mainThreadTasks_list,label = '3G')
plt.plot(websites_list, g4_mainThreadTasks_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("main-thread-tasks")
plt.legend()
plt.show()

plt.plot(websites_list, g2_thirdPartySummary_list,label = '2G')
plt.plot(websites_list, g3_thirdPartySummary_list,label = '3G')
plt.plot(websites_list, g4_thirdPartySummary_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("thirdPartySummary")
plt.legend()
plt.show()

plt.plot(websites_list, g2_totalByteWeight_list,label = '2G')
plt.plot(websites_list, g3_totalByteWeight_list,label = '3G')
plt.plot(websites_list, g4_totalByteWeight_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("total-byte-weight")
plt.legend()
plt.show()

plt.plot(websites_list, g2_usesHttp2_list,label = '2G')
plt.plot(websites_list, g3_usesHttp2_list,label = '3G')
plt.plot(websites_list, g4_usesHttp2_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("uses HTTP2")
plt.legend()
plt.show()

plt.plot(websites_list, g2_usesPassiveEventListeners_list,label = '2G')
plt.plot(websites_list, g3_usesPassiveEventListeners_list,label = '3G')
plt.plot(websites_list, g4_usesPassiveEventListeners_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("uses-passive-event-listeners")
plt.legend()
plt.show()

plt.plot(websites_list, g2_usesPassiveEventListeners_list,label = '2G')
plt.plot(websites_list, g3_usesPassiveEventListeners_list,label = '3G')
plt.plot(websites_list, g4_usesPassiveEventListeners_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("uses-passive-event-listeners")
plt.legend()
plt.show()

plt.plot(websites_list, g2_usesPlugins_list,label = '2G')
plt.plot(websites_list, g3_usesPlugins_list,label = '3G')
plt.plot(websites_list, g4_usesPlugins_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("plugins")
plt.legend()
plt.show()

plt.plot(websites_list, g2_SI_list,label = '2G')
plt.plot(websites_list, g3_SI_list,label = '3G')
plt.plot(websites_list, g4_SI_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("Speed Index")
plt.legend()
plt.show()

plt.plot(websites_list, g2_interactive_list,label = '2G')
plt.plot(websites_list, g3_interactive_list,label = '3G')
plt.plot(websites_list, g4_interactive_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("Interactive")
plt.legend()
plt.show()

plt.plot(websites_list, g2_1stContentfulPaint_list,label = '2G')
plt.plot(websites_list, g3_1stContentfulPaint_list,label = '3G')
plt.plot(websites_list, g4_1stContentfulPaint_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("First Contentful Paint")
plt.legend()
plt.show()

plt.plot(websites_list, g2_1stCpuIdle_list,label = '2G')
plt.plot(websites_list, g3_1stCpuIdle_list,label = '3G')
plt.plot(websites_list, g4_1stCpuIdle_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("First CPU Idle")
plt.legend()
plt.show()

plt.plot(websites_list, g2_1stMeaningfulPaint_list,label = '2G')
plt.plot(websites_list, g3_1stMeaningfulPaint_list,label = '3G')
plt.plot(websites_list, g4_1stMeaningfulPaint_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("First Meaningful Paint")
plt.legend()
plt.show()

# %%
root_dir = 'drive/My Drive/WirelessProject'
import glob   
import ntpath
import os

desktop_path = root_dir + '/desktop/*'
mobile_path = root_dir + '/mobile/'
desktop_files=glob.glob(desktop_path)
websites_list = list()
desktop_scriptEvaluation_list = list()
mobile_scriptEvaluation_list = list()
desktop_other_list = list()
mobile_other_list = list()
desktop_paintCompositeRender_list = list()
mobile_paintCompositeRender_list = list()
desktop_styleLayout_list = list()
mobile_styleLayout_list = list()
desktop_parseHTML_list = list()
mobile_parseHTML_list = list()
desktop_scriptParseCompile_list = list()
mobile_scriptParseCompile_list = list()
desktop_garbageCollection_list = list()
mobile_garbageCollection_list = list()

for desktop_file in desktop_files:
  head, tail = ntpath.split(desktop_file)
  websites_list.append(os.path.splitext(tail)[0])
  json_file = open(desktop_file)
  json_data = json.load(json_file)
  mobile_json_file = open(mobile_path + tail)
  mobile_json_data = json.load(mobile_json_file)
  for i in range(7):
    if not(i == 6 and os.path.splitext(tail)[0] == "www.gov.uk"):
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptEvaluation":
        desktop_scriptEvaluation_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "other":
        desktop_other_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "paintCompositeRender":
        desktop_paintCompositeRender_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "styleLayout":
        desktop_styleLayout_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "parseHTML":
        desktop_parseHTML_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptParseCompile":
        desktop_scriptParseCompile_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "garbageCollection":
        desktop_garbageCollection_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    else:
      desktop_garbageCollection_list.append(0)
    if not(i == 6 and os.path.splitext(tail)[0] == "www.wikipedia.org"):
      if mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptEvaluation":
        mobile_scriptEvaluation_list.append(mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "other":
        mobile_other_list.append(mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "paintCompositeRender":
        mobile_paintCompositeRender_list.append(mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "styleLayout":
        mobile_styleLayout_list.append(mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "parseHTML":
        mobile_parseHTML_list.append(mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptParseCompile":
        mobile_scriptParseCompile_list.append(mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "garbageCollection":
        mobile_garbageCollection_list.append(mobile_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    else:
      mobile_garbageCollection_list.append(0)

# %%
websites_list = list()
g2_scriptEvaluation_list = list()
g3_scriptEvaluation_list = list()
g4_scriptEvaluation_list = list()
g2_other_list = list()
g3_other_list = list()
g4_other_list = list()
g2_paintCompositeRender_list = list()
g3_paintCompositeRender_list = list()
g4_paintCompositeRender_list = list()
g2_styleLayout_list = list()
g3_styleLayout_list = list()
g4_styleLayout_list = list()
g2_parseHTML_list = list()
g3_parseHTML_list = list()
g4_parseHTML_list = list()
g2_scriptParseCompile_list = list()
g3_scriptParseCompile_list = list()
g4_scriptParseCompile_list = list()
g2_garbageCollection_list = list()
g3_garbageCollection_list = list()
g4_garbageCollection_list = list()

#for g2_file in g2_files:
for desktop_file in desktop_files:
  head, tail = ntpath.split(desktop_file)
  websites_list.append(os.path.splitext(tail)[0])
  #print(os.path.splitext(tail)[0])
  json_file = open(g2_path + tail)
  json_data = json.load(json_file)
  g3_json_file = open(g3_path + tail)
  g3_json_data = json.load(g3_json_file)
  g4_json_file = open(g4_path + tail)
  g4_json_data = json.load(g4_json_file)
  for i in range(6):
    if not(i == 6 and os.path.splitext(tail)[0] == "www.gov.uk"):
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptEvaluation":
        g2_scriptEvaluation_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "other":
        g2_other_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "paintCompositeRender":
        g2_paintCompositeRender_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "styleLayout":
        g2_styleLayout_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "parseHTML":
        g2_parseHTML_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptParseCompile":
        g2_scriptParseCompile_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
      if json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "garbageCollection":
        g2_garbageCollection_list.append(json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    else:
      g2_garbageCollection_list.append(0)
    #if not(i == 6 and os.path.splitext(tail)[0] == "www.wikipedia.org"):
    if g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptEvaluation":
      g3_scriptEvaluation_list.append(g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "other":
      g3_other_list.append(g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "paintCompositeRender":
      g3_paintCompositeRender_list.append(g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "styleLayout":
      g3_styleLayout_list.append(g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "parseHTML":
      g3_parseHTML_list.append(g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptParseCompile":
      g3_scriptParseCompile_list.append(g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "garbageCollection":
      g3_garbageCollection_list.append(g3_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    #else:
    #  g3_garbageCollection_list.append(0)
    if g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptEvaluation":
      g4_scriptEvaluation_list.append(g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "other":
      g4_other_list.append(g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "paintCompositeRender":
      g4_paintCompositeRender_list.append(g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "styleLayout":
      g4_styleLayout_list.append(g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "parseHTML":
      g4_parseHTML_list.append(g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "scriptParseCompile":
      g4_scriptParseCompile_list.append(g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
    if g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["group"] == "garbageCollection":
      g4_garbageCollection_list.append(g4_json_data["audits"]["mainthread-work-breakdown"]["details"]["items"][i]["duration"])
  #print()

# %%
plt.plot(websites_list, desktop_scriptEvaluation_list,label = 'Desktop')
plt.plot(websites_list, mobile_scriptEvaluation_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("scriptEvaluation")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_other_list,label = 'Desktop')
plt.plot(websites_list, mobile_other_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("other")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_paintCompositeRender_list,label = 'Desktop')
plt.plot(websites_list, mobile_paintCompositeRender_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("paintCompositeRender")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_styleLayout_list,label = 'Desktop')
plt.plot(websites_list, mobile_styleLayout_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("styleLayout")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_parseHTML_list,label = 'Desktop')
plt.plot(websites_list, mobile_parseHTML_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("parseHTML")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_scriptParseCompile_list,label = 'Desktop')
plt.plot(websites_list, mobile_scriptParseCompile_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("scriptParseCompile")
plt.legend()
plt.show()

plt.plot(websites_list, desktop_garbageCollection_list,label = 'Desktop')
plt.plot(websites_list, mobile_garbageCollection_list,label = 'Mobile')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("garbageCollection")
plt.legend()
plt.show()

# %%
plt.plot(websites_list, g2_scriptEvaluation_list,label = '2G')
plt.plot(websites_list, g3_scriptEvaluation_list,label = '3G')
plt.plot(websites_list, g4_scriptEvaluation_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("scriptEvaluation")
plt.legend()
plt.show()

plt.plot(websites_list, g2_other_list,label = '2G')
plt.plot(websites_list, g3_other_list,label = '3G')
plt.plot(websites_list, g4_other_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("other")
plt.legend()
plt.show()

plt.plot(websites_list, g2_paintCompositeRender_list,label = '2G')
plt.plot(websites_list, g3_paintCompositeRender_list,label = '3G')
plt.plot(websites_list, g4_paintCompositeRender_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("paintCompositeRender")
plt.legend()
plt.show()

plt.plot(websites_list, g2_styleLayout_list,label = '2G')
plt.plot(websites_list, g3_styleLayout_list,label = '3G')
plt.plot(websites_list, g4_styleLayout_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("styleLayout")
plt.legend()
plt.show()

plt.plot(websites_list, g2_parseHTML_list,label = '2G')
plt.plot(websites_list, g3_parseHTML_list,label = '3G')
plt.plot(websites_list, g4_parseHTML_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("parseHTML")
plt.legend()
plt.show()

plt.plot(websites_list, g2_scriptParseCompile_list,label = '2G')
plt.plot(websites_list, g3_scriptParseCompile_list,label = '3G')
plt.plot(websites_list, g4_scriptParseCompile_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("scriptParseCompile")
plt.legend()
plt.show()

# plt.plot(websites_list, g2_garbageCollection_list,label = '2G')
# plt.plot(websites_list, g3_garbageCollection_list,label = '3G')
# plt.plot(websites_list, g4_garbageCollection_list,label = '4G')
# plt.xticks(rotation = 90)
# plt.xlabel("Sites")
# plt.ylabel("garbageCollection")
# plt.legend()
# plt.show()

# %%
websites_list = list()
# g2_noOfReq_list = list()
# g3_noOfReq_list = list()
# g4_noOfReq_list = list()
g2_TS_list = list()
g3_TS_list = list()
g4_TS_list = list()

#for g2_file in g2_files:
for desktop_file in desktop_files:
  head, tail = ntpath.split(desktop_file)
  websites_list.append(os.path.splitext(tail)[0])
  #print(os.path.splitext(tail)[0])
  json_file = open(g2_path + tail)
  json_data = json.load(json_file)
  g3_json_file = open(g3_path + tail)
  g3_json_data = json.load(g3_json_file)
  g4_json_file = open(g4_path + tail)
  g4_json_data = json.load(g4_json_file)
  g2_noOfReq_list = json_data["audits"]["network-requests"]["numericValue"]
  g3_noOfReq_list = g3_json_data["audits"]["network-requests"]["numericValue"]
  g4_noOfReq_list = g4_json_data["audits"]["network-requests"]["numericValue"]
  total_TS = 0
  for count in range(g2_noOfReq_list):
    total_TS += json_data["audits"]["network-requests"]["details"]["items"][i]["transferSize"]
  g2_TS_list.append(total_TS)
  total_TS1 = 0
  for count in range(g3_noOfReq_list):
    total_TS1 += json_data["audits"]["network-requests"]["details"]["items"][i]["transferSize"]
  g3_TS_list.append(total_TS1)
  total_TS2 = 0
  for count in range(g4_noOfReq_list):
    total_TS2 += json_data["audits"]["network-requests"]["details"]["items"][i]["transferSize"]
  g4_TS_list.append(total_TS2)

plt.plot(websites_list, g2_TS_list,label = '2G')
plt.plot(websites_list, g3_TS_list,label = '3G')
plt.plot(websites_list, g4_TS_list,label = '4G')
plt.xticks(rotation = 90)
plt.xlabel("Sites")
plt.ylabel("Transfer Size")
plt.legend()
plt.show()
